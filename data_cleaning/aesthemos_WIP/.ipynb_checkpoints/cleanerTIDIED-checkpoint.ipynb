# %% [markdown]
# # AESTHEMOS
# For use with data collected from
#
# ## TO-DO:
# ### fix missing IDS
# * names w/ accents
# * accents mess up comparisons -> can't ID
# * Édouard Vuillard! -> Ãˆdouard Vuillard
#
#
# ### make function for computation and loop through all output files
# ### decide how to group
# ### remove all work except functions and loops

# %% [markdown]
# AESTHEMOS (based on this):
# This is the meat of this project. This is a measure that evaluates the subject's aesthetic experiences of each of the paintings they view. There should be about 66-67 paintings they view, and for 8 different categories of emotion, the subject gives a score between 1-7 based on intensity of that emotion.
# There are 7 different form files, one for each different gallery (because it was too big to put in one form ): They are in questionnaires>Google Forms>AESTHEMOS
# We want to divide all the paintings into one of 5 categories based on each individual's ratings: High Arousal Positive Valence, High Arousal Negative Valence, Low Arousal Positive Valence, Low Arousal Negative Valence, and Indifferent. This is calculated by:
# Sort the paintings by the "Indifference" score. The top 10 with the highest Indifference scores will be part of the 'indiff' group.
# Take out the 'indiff' group. Using the remaining paintings, create an "Arousal" measure which is the sum of ['a. Moved']+df['b. Fascinated']+df['c. Funny']+df['d. Surprised']
# Sort paintings by Arousal; split in half. The ones with higher arousal scores go in the high arousal group, the ones with lower arousal scores go in the low arousal group.
# Within each of those arousal groups, sort by "Unsettling". Split in half. If the Unsettled score is low, it's in the positive group, if it's high, then it's in the negative group.
# At this point you should have the 5 groups: hiPos, hiNeg, loPos, loNeg, and indiff. Create a csv that has a row for each painting and these columns: Painting Title, Artist, Gallery number, Unique ID, and the name of the Group it's in, as well as a column for each of the original measures on their ratings. I've attached a file called 'pilot02-groups-2-titles.csv' for reference; ultimately we want a file for each participant that looks like that but also includes all of the original ratings. The name of the file should be 'pilot__-groups.csv'
# I have a Python script that I've used in the past that I can share with you if you like, but it was written for a different style of input (not a Google Form export) and also it's a mess haha.

# %%
import pandas as pd
from numpy import array
import os

# %%
# Fixes numerical values in gallery files AND makes unique subject list
unique_subjects = set()
for gallery in os.listdir('data/aesthemos'):
    if gallery.endswith(".csv"):
        g = pd.read_csv("data/aesthemos/" + gallery).replace({'1 - Not at all':1, '7 - Strongly':7})
        g_subs = g['Subject #:'].tolist()
        z = [x.replace(' ', '').lower() for x in g_subs]
        unique_subjects = unique_subjects.union(set(z))
        g.to_csv("data/aesthemos/" + gallery, index=False)
list(unique_subjects)
# Out:
# ['pilot01', 'pilot02']

# %%
# Setup key for painting IDs
IDsTable = pd.read_csv("paintingIDsKey.csv", encoding='latin1')
# Out:
#                                                 Title  \
# 0                              Composition with Boats
# 1                                            Untitled
# 2            Still-life Synchromy with Nude in Yellow
# 3                                            Untitled
# 4                                        Morning News
# 5                                               Mukie
# 6                                         Formation I
# 7                               Pool in the Mountains
# 8                             Late Afternoon, Giverny
# 9                              The Edge of the Forest
# 10                                        Junior Camp
# 11                         Portrait in Grey and Black
# 12                       Elizabeth Crowell with a Dog
# 13                               Blue, White and Gold
# 14        Portrait of Colonel James Hervey Birch, Jr.
# 15                     Portrait of Mrs. William Crane
# 16  Farm Landscape, Cattle in Pasture--Sunset Nant...
# 50                         Martn Bernat       1604
# 51                       Luca Signorelli       1622
# 52                        Carlo Crivelli       1609
# 53      Pseudo Pier Francesco Fiorentino       1619
# 54                     Giovanni di Paolo       1610
# 55                     Antonio de Bellis       1603
# 56                        Giovanni Bonsi       1605
# 57                        Berthe Morisot       1908
# 58             Henri de Toulouse-Lautrec       1909
# 59                       Maximilien Luce       1906
# 60                      douard Vuillard       1910
# 61                        Georges Braque       1903
# 62                     Sorolla y Bastida      20001
# 63                     Sorolla y Bastida      20002
# 64                              Bellotto      20006
# 65                                  Dufy      20003
#
# [66 rows x 3 columns]

# %%
def clean_single_gallery(filesource, sub):
    file = pd.read_csv(filesource)
    sub_ser = pd.Series([x.replace(' ', '').lower() for x in file['Subject #:']])
    
    table = file.loc[sub_ser == sub].T.reset_index().drop([0,1]).rename(columns={"index": "Title"})
    if len(table.columns) > 1:
        table = (
            table
            .assign(category=table.Title.apply(lambda x: x.split(" ")[-1]))
            .assign(Name=table.Title.apply(lambda x: " ".join(x.split(" ")[:-1])))
            .rename(columns={ table.columns[-1]: "score"})
            .drop('Title', axis=1) 
         )
        table = table.assign(score=table.score.astype(int))
        t = table.pivot_table(index='Name', columns='category', aggfunc=(lambda x: x))
        t.columns = t.columns.levels[1].rename(None)
        t = t.rename(columns=lambda x: x[1:-1]).reset_index()
        art_split = t.Name.str.split(" by ", expand=True)
        t['Title'] = art_split[0]
        t['Artist'] = art_split[1]
        t = t.drop('Name', axis=1)
        t = pd.merge(t, IDsTable, how='left', on=['Title', 'Artist']) #SOME PAINTINGS DISSAPEAR
        return t
    else:
        print("ERROR: " + sub + " not in " + filesource)
        return;

# %%
# CONVERT ALL GALLERY FILES INTO SEPERATE SUBJECT CSVS
for subject in unique_subjects:
    current_sub = pd.DataFrame(
        columns = ["Title", "Artist" "Beautiful", "Calm", "Fascinated", "Funny", "Indifferent", "Moved", "Surprised", "Unsettled"]
    )
    for gallery in os.listdir('data/aesthemos'):
        if gallery.endswith(".csv"):
            fix_curr = clean_single_gallery("data/aesthemos/" + gallery, subject)
            if fix_curr is not None:
                fix_curr['Gallery'] = gallery.split()[1].replace(".csv", "")
                current_sub = current_sub.append(fix_curr, ignore_index = True, sort=True)
    current_sub.to_csv("output/"+ subject + "-groups.csv", index=False)

# %%
fix_curr
# Out:
#    Beautiful  Calm  Fascinated  Funny  Indifferent  Moved  Surprised  \
# 0          4     5           3      1            3      3          3
# 1          5     5           5      1            2      4          5
# 2          3     5           2      1            5      1          2
# 3          3     5           2      1            5      2          3
# 4          3     5           2      1            5      2          3
# 5          4     5           3      1            3      2          3
# 6          3     5           2      1            4      2          2
# 7          3     5           2      1            5      1          2
# 8          3     5           2      1            5      1          2
#
#    Unsettled                          Title   Artist  Unique ID Gallery
# 0          1               Afternoon Stroll    Chase      10003     100
# 1          2              Eve of Saint John     Hurd      10005     100
# 2          1                Game of Croquet    Fries      10008     100
# 3          1           Rock ledge in Autumn    Braun      10007     100
# 4          1              San Felipe Valley  Reiffel      10004     100
# 5          1                    Sierra Lake    Payne      10009     100
# 6          1  Southern California Landscape    Braun      10002     100
# 7          1               The White Flower  O'Keefe      10001     100
# 8          1                   Torrey Pines   Fechin      10010     100

# %% [markdown]
# # Group Computation/Column Cleanup

# %%
# for loop processing each file to add computation stuff needed for catagories

# %%
fs = ("output/"+ "pilot02" + "-groups.csv")
file = pd.read_csv(fs)
df = file.sort_values("Indifferent") #lots of indifferent scores are the same...how do you want to further seperate
indiff = df.tail(10)
others = df.iloc[:-10]
print(len(df), len(indiff), len(others))
# Out:
# 66 10 56

# %%
indiff["Group"] = "indiff"
indiff
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                        Artist  ArtistBeautiful  Beautiful  Calm  Fascinated  \
# 14               Thomas Moran              NaN        3.0     5           2
# 11            Emil J. Carlsen              NaN        2.0     5           1
# 5          Thomas Hart Benton              NaN        2.0     5           2
# 4              Berthe Morisot              NaN        3.0     5           2
# 3   Henri de Toulouse-Lautrec              NaN        2.0     5           2
# 2              Georges Braque              NaN        2.0     5           2
# 1            Èdouard Vuillard              NaN        2.0     5           2
# 45                   Bellotto              NaN        3.0     5           2
# 65                     Fechin              NaN        3.0     5           2
# 41  Giovanni Battista Pittoni              NaN        3.0     5           2
#
#     Funny  Gallery  Indifferent  Moved  Surprised  \
# 14      1        2            5      2          2
# 11      1        2            5      1          2
# 5       1        3            5      2          2
# 4       1       19            5      1          2
# 3       2       19            5      1          1
# 2       2       19            5      1          1
# 1       1       19            5      1          2
# 45      1      200            5      2          2
# 65      1      100            5      1          2
# 41      2       16            6      1          2
#
#                                            Title  Unique ID  Unsettled   Group
# 14                                Indian Village     2010.0          1  indiff
# 11                          Blue, White and Gold     2019.0          1  indiff
# 5                                After Many Days     3003.0          2  indiff
# 4                       The Seine Valley at Mézy        NaN          1  indiff
# 3       The Masked Ball at the Elysée Montmartre        NaN          1  indiff
# 2                               The Corn-poppies     1903.0          1  indiff
# 1                       Tea at Madame Vuillard's        NaN          1  indiff
# 45  The Molo from the Basin of San Marco, Venice        NaN          1  indiff
# 65                                  Torrey Pines    10010.0          1  indiff
# 41          The Vision of Saint Anthony of Padua     1617.0          1  indiff

# %%
indiff[indiff["Calm"] > 5]
# Out:
# Empty DataFrame
# Columns: [Artist, ArtistBeautiful, Beautiful, Calm, Fascinated, Funny, Gallery, Indifferent, Moved, Surprised, Title, Unique ID, Unsettled, Group]
# Index: []

# %%
# create arousal (Moved + Fascinated + Funny + Surprised)
arousal = others['Moved'] + others['Fascinated'] + others['Funny'] + others['Surprised']
others["Arousal"] = arousal


# add high/low column to others
others = others.sort_values("Arousal")
others
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                   Artist  ArtistBeautiful  Beautiful  Calm  \
# 27                    Fransesco Vecellio              NaN        1.0     1
# 20                       Emil J. Carlsen              NaN        2.0     5
# 16                           Henry Inman              NaN        3.0     5
# 64                               O'Keefe              NaN        3.0     5
# 59                                 Fries              NaN        3.0     5
# 55                  George Copeland Ault              NaN        3.0     5
# 25                        Carlo Crivelli              NaN        3.0     4
# 32           follower of Pietro Perugino              NaN        3.0     5
# 49                      Guy Orlando Rose              NaN        3.0     4
# 63                                 Braun              NaN        3.0     5
# 9                          George Wesley              NaN        2.0     4
# 17                  Eduard Jean Steichen              NaN        3.0     4
# 0                        Maximilien Luce              NaN        3.0     4
# 61                               Reiffel              NaN        3.0     5
# 60                                 Braun              NaN        3.0     5
# 40              Giulio Cesare Procaccini              NaN        3.0     3
# 10                          Hans Hofmann              NaN        2.0     4
# 23  Vincenzo Catena (Vincenzo di Biagio)              NaN        3.0     5
# 54                     Theodore Robinson              NaN        3.0     5
# 50                     Francis Luis Mora              NaN        3.0     4
# 62                                 Payne              NaN        4.0     5
# 8                       Hughie Lee-Smith              NaN        3.0     4
# 12                        Thomas Easkins              NaN        3.0     4
# 51                          Robert Henri              NaN        3.0     4
# 47                  Arthur Garfield Dove              NaN        2.0     5
# 33                        Giovanni Bonsi              NaN        3.0     4
# 43                     Sorolla y Bastida              NaN        4.0     5
# 30                  Bartolommeo Vivarini              NaN        3.0     4
# 57                                 Chase              NaN        4.0     5
# 13                         George Inness              NaN        3.0     4
# 24                          His Brothers              NaN        4.0     3
# 34                    The Astorga Master              NaN        4.0     5
# 18                  George Caleb Bingham              NaN        3.0     4
# 26                     Giovanni di Paolo              NaN        4.0     4
# 48                         Daniel Garber              NaN        4.0     4
# 53                        Morgan Russell              NaN        2.0     4
# 56                           Janet Sobel              NaN        2.0     4
# 42                     Sorolla y Bastida              NaN        4.0     5
# 46                          Stuart Davis              NaN        2.0     5
# 6                   José Agustin Arrieta              NaN        4.0     5
# 28                  Giuliano Burgiardini              NaN        5.0     5
# 38                         Martin Bernat              NaN        4.0     3
# 19                    Sarah Miriam Peale              NaN        5.0     4
# 31                   Master of Frankfurt              NaN        5.0     5
# 21                     Antonio de Bellis              NaN        5.0     3
# 7                        Raphaelle Peale              NaN        5.0     5
# 39                    Peter Paul Reubens              NaN        6.0     6
# 37                       Luca Signorelli              NaN        5.0     5
# 58                                  Hurd              NaN        5.0     5
# 29      Pseudo Pier Francesco Fiorentino              NaN        5.0     5
# 15                       Jules Tavernier              NaN        5.0     5
# 35                             de Ribera              NaN        4.0     5
# 44                                  Dufy              NaN        6.0     5
# 36                      Hieronymus Bosch              NaN        4.0     5
# 52                          Milton Avery              NaN        1.0     5
# 22                        Daniel Seghers              NaN        7.0     5
#
#     Fascinated  Funny  Gallery  Indifferent  Moved  Surprised  \
# 27           1      1       16            1      1          1
# 20           2      1        2            5      1          1
# 16           2      1        2            5      1          2
# 64           2      1      100            5      1          2
# 59           2      1      100            5      1          2
# 55           2      1        1            5      1          2
# 25           3      1       16            5      2          1
# 32           2      2       16            5      1          2
# 49           2      1        1            4      2          2
# 63           2      1      100            4      2          2
# 9            2      1        3            4      2          2
# 17           2      1        2            4      2          2
# 0            3      1       19            4      2          1
# 61           2      1      100            5      2          3
# 60           2      1      100            5      2          3
# 40           3      1       16            4      2          2
# 10           1      4        3            3      1          2
# 23           3      1       16            5      3          2
# 54           3      1        1            5      2          3
# 50           3      1        1            4      2          3
# 62           3      1      100            3      2          3
# 38                                    The Crucifixion        NaN          4
# 19                     Portrait of Mrs. William Crane     2011.0          1
# 31               Mystical Marriage of Saint Catherine     1613.0          1
# 21                         David with Head of Goliath     1603.0          3
# 7                             Still-life with Peaches     3007.0          1
# 39  The Holy Family with Saints Francis, Anne, and...        NaN          1
# 37                       The Coronation of the Virgin     1622.0          1
# 58                                  Eve of Saint John    10005.0          2
# 29                               Madonna of the Roses     1619.0          1
# 15                  Kilauea Caldera, Sandwich Islands     2013.0          2
# 35                             Susanna and the Elders     1628.0          3
# 44                                     Seine in Parin    20003.0          1
# 36                               The Arrest of Christ     1606.0          2
# 52                              Pool in the Mountains     1002.0          1
# 22                Flower Garland with the Holy Family     1621.0          1
#
#     Arousal
# 27        4
# 20        5
# 16        6
# 64        6
# 59        6
# 55        6
# 25        7
# 32        7
# 49        7
# 63        7
# 9         7
# 17        7
# 0         7
# 61        8
# 60        8
# 40        8
# 10        8
# 23        9
# 54        9
# 50        9
# 62        9
# 8         9
# 12       10
# 51       10
# 47       10
# 33       10
# 43       10
# 30       10
# 57       10
# 13       11
# 24       11
# 34       11
# 18       11
# 26       11
# 48       11
# 53       11
# 56       11
# 42       12
# 46       12
# 6        12
# 28       12
# 38       12
# 19       13
# 31       13
# 21       14
# 7        14
# 39       14
# 37       14
# 58       15
# 29       15
# 15       15
# 35       16
# 44       16
# 36       16
# 52       16
# 22       20

# %%
### middle value split
"""
low = others.head(int(len(others)/2))
low["hilo"] = "lo"
high = others.tail(int(len(others)/2))
high["hilo"] = "hi"
"""

### Mean value split

aro_mean = others["Arousal"].mean() + 0.00001 # making non int should eliminate = mean
low = others[others["Arousal"] < aro_mean]
low["hilo"] = "lo"
high = others[others["Arousal"] > aro_mean]
high["hilo"] = "hi"



full_aro = pd.concat([low, high]).sort_values("Unsettled")
full_aro
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                                   Artist  ArtistBeautiful  Beautiful  Calm  \
# 27                    Fransesco Vecellio              NaN        1.0     1
# 43                     Sorolla y Bastida              NaN        4.0     5
# 52                          Milton Avery              NaN        1.0     5
# 57                                 Chase              NaN        4.0     5
# 34                    The Astorga Master              NaN        4.0     5
# 18                  George Caleb Bingham              NaN        3.0     4
# 26                     Giovanni di Paolo              NaN        4.0     4
# 48                         Daniel Garber              NaN        4.0     4
# 53                        Morgan Russell              NaN        2.0     4
# 56                           Janet Sobel              NaN        2.0     4
# 33                        Giovanni Bonsi              NaN        3.0     4
# 42                     Sorolla y Bastida              NaN        4.0     5
# 6                   José Agustin Arrieta              NaN        4.0     5
# 28                  Giuliano Burgiardini              NaN        5.0     5
# 19                    Sarah Miriam Peale              NaN        5.0     4
# 31                   Master of Frankfurt              NaN        5.0     5
# 7                        Raphaelle Peale              NaN        5.0     5
# 39                    Peter Paul Reubens              NaN        6.0     6
# 37                       Luca Signorelli              NaN        5.0     5
# 29      Pseudo Pier Francesco Fiorentino              NaN        5.0     5
# 44                                  Dufy              NaN        6.0     5
# 46                          Stuart Davis              NaN        2.0     5
# 47                  Arthur Garfield Dove              NaN        2.0     5
# 43       10   lo
# 52       16   hi
# 57       10   lo
# 34       11   hi
# 18       11   hi
# 26       11   hi
# 48       11   hi
# 53       11   hi
# 56       11   hi
# 33       10   lo
# 42       12   hi
# 6        12   hi
# 28       12   hi
# 19       13   hi
# 31       13   hi
# 7        14   hi
# 39       14   hi
# 37       14   hi
# 29       15   hi
# 44       16   hi
# 46       12   hi
# 47       10   lo
# 30       10   lo
# 12       10   lo
# 20        5   lo
# 16        6   lo
# 64        6   lo
# 59        6   lo
# 55        6   lo
# 25        7   lo
# 32        7   lo
# 49        7   lo
# 51       10   lo
# 17        7   lo
# 0         7   lo
# 63        7   lo
# 60        8   lo
# 62        9   lo
# 50        9   lo
# 61        8   lo
# 23        9   lo
# 54        9   lo
# 22       20   hi
# 13       11   hi
# 10        8   lo
# 58       15   hi
# 9         7   lo
# 15       15   hi
# 8         9   lo
# 36       16   hi
# 21       14   hi
# 35       16   hi
# 38       12   hi
# 24       11   hi
# 40        8   lo

# %%
# make pos/neg based off of Unsettled from full_aro

### middle value split
"""
neg = full_aro.head(int(len(full_aro)/2))
neg["PosNeg"] = "Neg"
pos = full_aro.tail(int(len(full_aro)/2))
pos["PosNeg"] = "Pos"
"""

### Mean value split

unset_mean = full_aro["Unsettled"].mean() + 0.00001 # making non int should eliminate = mean
neg = full_aro[full_aro["Unsettled"] < unset_mean]
neg["PosNeg"] = "Neg"
pos = full_aro[full_aro["Unsettled"] > unset_mean]
pos["PosNeg"] = "Pos"

pos
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                       Artist  ArtistBeautiful  Beautiful  Calm  Fascinated  \
# 13             George Inness              NaN        3.0     4           2
# 10              Hans Hofmann              NaN        2.0     4           1
# 58                      Hurd              NaN        5.0     5           5
# 9              George Wesley              NaN        2.0     4           2
# 15           Jules Tavernier              NaN        5.0     5           5
# 8           Hughie Lee-Smith              NaN        3.0     4           3
# 36          Hieronymus Bosch              NaN        4.0     5           3
# 21         Antonio de Bellis              NaN        5.0     3           5
# 35                 de Ribera              NaN        4.0     5           5
# 38             Martin Bernat              NaN        4.0     3           4
# 24              His Brothers              NaN        4.0     3           5
# 40  Giulio Cesare Procaccini              NaN        3.0     3           3
#
#     Funny  Gallery  Indifferent  Moved  Surprised  \
# 13      4        2            3      1          4
# 10      4        3            3      1          2
# 58      1      100            2      4          5
# 9       1        3            4      2          2
# 15      1        2            2      4          5
# 8       1        3            3      2          3
# 36      5       16            2      3          5
# 21      1       16            2      4          4
# 35      1       16            2      5          5
# 38      1       16            2      4          3
# 24      1       16            3      3          2
# 40      1       16            4      2          2
#
#                                                 Title  Unique ID  Unsettled  \
# 13  Farm Landscape, Cattle in Pasture--Sunset Nant...     2008.0          2
# 10                                       Woman Seated     3009.0          2
# 58                                  Eve of Saint John    10005.0          2
# 9                           Three Pigs and a Mountain        NaN          2
# 15                  Kilauea Caldera, Sandwich Islands     2013.0          2
# 8                                    Sunday Afternoon     3005.0          2
# 36                               The Arrest of Christ     1606.0          2
# 21                         David with Head of Goliath     1603.0          3
# 35                             Susanna and the Elders     1628.0          3
# 38                                    The Crucifixion        NaN          4
# 24                                        Joseph Sold        NaN          5
# 40                             The Penitent Magdalene     1618.0          5
#
#     Arousal hilo PosNeg
# 13       11   hi    Pos
# 10        8   lo    Pos
# 58       15   hi    Pos
# 9         7   lo    Pos
# 15       15   hi    Pos
# 8         9   lo    Pos
# 36       16   hi    Pos
# 21       14   hi    Pos
# 35       16   hi    Pos
# 38       12   hi    Pos
# 24       11   hi    Pos
# 40        8   lo    Pos

# %%
#merge hilow/posneg and make groups col
final_df = pd.concat([pos, neg])
final_df["Group"] = final_df["hilo"] + final_df["PosNeg"]

final_df = final_df.drop(columns=["hilo", "PosNeg"])
final_df
# Out:
#                                   Artist  ArtistBeautiful  Beautiful  Calm  \
# 13                         George Inness              NaN        3.0     4
# 10                          Hans Hofmann              NaN        2.0     4
# 58                                  Hurd              NaN        5.0     5
# 9                          George Wesley              NaN        2.0     4
# 15                       Jules Tavernier              NaN        5.0     5
# 8                       Hughie Lee-Smith              NaN        3.0     4
# 36                      Hieronymus Bosch              NaN        4.0     5
# 21                     Antonio de Bellis              NaN        5.0     3
# 35                             de Ribera              NaN        4.0     5
# 38                         Martin Bernat              NaN        4.0     3
# 24                          His Brothers              NaN        4.0     3
# 40              Giulio Cesare Procaccini              NaN        3.0     3
# 27                    Fransesco Vecellio              NaN        1.0     1
# 43                     Sorolla y Bastida              NaN        4.0     5
# 52                          Milton Avery              NaN        1.0     5
# 57                                 Chase              NaN        4.0     5
# 34                    The Astorga Master              NaN        4.0     5
# 18                  George Caleb Bingham              NaN        3.0     4
# 26                     Giovanni di Paolo              NaN        4.0     4
# 48                         Daniel Garber              NaN        4.0     4
# 53                        Morgan Russell              NaN        2.0     4
# 56                           Janet Sobel              NaN        2.0     4
# 33                        Giovanni Bonsi              NaN        3.0     4
# 42                     Sorolla y Bastida              NaN        4.0     5
# 6                   José Agustin Arrieta              NaN        4.0     5
# 28                  Giuliano Burgiardini              NaN        5.0     5
# 19                    Sarah Miriam Peale              NaN        5.0     4
# 31                   Master of Frankfurt              NaN        5.0     5
# 7                        Raphaelle Peale              NaN        5.0     5
# 39                    Peter Paul Reubens              NaN        6.0     6
# 37                       Luca Signorelli              NaN        5.0     5
# 29      Pseudo Pier Francesco Fiorentino              NaN        5.0     5
# 44                                  Dufy              NaN        6.0     5
# 46                          Stuart Davis              NaN        2.0     5
# 47                  Arthur Garfield Dove              NaN        2.0     5
# 30                  Bartolommeo Vivarini              NaN        3.0     4
# 12                        Thomas Easkins              NaN        3.0     4
# 20                       Emil J. Carlsen              NaN        2.0     5
# 16                           Henry Inman              NaN        3.0     5
# 64                               O'Keefe              NaN        3.0     5
# 59                                 Fries              NaN        3.0     5
# 55                  George Copeland Ault              NaN        3.0     5
# 25                        Carlo Crivelli              NaN        3.0     4
# 32           follower of Pietro Perugino              NaN        3.0     5
# 49                      Guy Orlando Rose              NaN        3.0     4
# 51                          Robert Henri              NaN        3.0     4
# 17                  Eduard Jean Steichen              NaN        3.0     4
# 0                        Maximilien Luce              NaN        3.0     4
# 34                                        Saint Peter     1601.0          1
# 18        Portrait of Colonel James Hervey Birch, Jr.     2002.0          1
# 26                      Madonna and Child with Angels     1610.0          1
# 48                                        Junior Camp     1007.0          1
# 53           Still-life Synchromy with Nude in Yellow     1013.0          1
# 56                                           Untitled     1014.0          1
# 33                             Saint Nicholas of Bari     1605.0          1
# 42                                    By the Seashore    20001.0          1
# 6                                          Still-life        NaN          1
# 28  Madonna and Child with the Young Saint John th...     1607.0          1
# 19                     Portrait of Mrs. William Crane     2011.0          1
# 31               Mystical Marriage of Saint Catherine     1613.0          1
# 7                             Still-life with Peaches     3007.0          1
# 39  The Holy Family with Saints Francis, Anne, and...        NaN          1
# 37                       The Coronation of the Virgin     1622.0          1
# 29                               Madonna of the Roses     1619.0          1
# 44                                     Seine in Parin    20003.0          1
# 46                             Composition with Boats     1005.0          1
# 47                                        Formation I     1006.0          1
# 30                     Male Saint, perhaps Saint Mark     1625.0          1
# 12                       Elizabeth Crowell with a Dog     2006.0          1
# 20                                         Still-life     2003.0          1
# 16                                           Mr. Paff     2007.0          1
# 64                                   The White Flower    10001.0          1
# 59                                    Game of Croquet    10008.0          1
# 55                                           Untitled     1001.0          1
# 25                                  Madonna and Child     1609.0          1
# 32                     Saint Jerome in the Wilderness        NaN          1
# 49                            Late Afternoon, Giverny     1012.0          1
# 51                                              Mukie     1009.0          1
# 17                         Portrait in Grey and Black     2012.0          1
# 0                                          Notre Dame     1906.0          1
# 63                      Southern California Landscape    10002.0          1
# 60                               Rock ledge in Autumn    10007.0          1
# 62                                        Sierra Lake    10009.0          1
# 50                                       Morning News     1010.0          1
# 61                                  San Felipe Valley    10004.0          1
# 23                        Holy Family with Saint Anne        NaN          1
# 54                             The Edge of the Forest     1011.0          1
# 22                Flower Garland with the Holy Family     1621.0          1
#
#     Arousal  Group
# 13       11  hiPos
# 10        8  loPos
# 58       15  hiPos
# 9         7  loPos
# 15       15  hiPos
# 8         9  loPos
# 36       16  hiPos
# 21       14  hiPos
# 35       16  hiPos
# 38       12  hiPos
# 24       11  hiPos
# 40        8  loPos
# 27        4  loNeg
# 43       10  loNeg
# 52       16  hiNeg
# 57       10  loNeg
# 34       11  hiNeg
# 18       11  hiNeg
# 26       11  hiNeg
# 48       11  hiNeg
# 53       11  hiNeg
# 56       11  hiNeg
# 33       10  loNeg
# 42       12  hiNeg
# 6        12  hiNeg
# 28       12  hiNeg
# 19       13  hiNeg
# 31       13  hiNeg
# 7        14  hiNeg
# 39       14  hiNeg
# 37       14  hiNeg
# 29       15  hiNeg
# 44       16  hiNeg
# 46       12  hiNeg
# 47       10  loNeg
# 30       10  loNeg
# 12       10  loNeg
# 20        5  loNeg
# 16        6  loNeg
# 64        6  loNeg
# 59        6  loNeg
# 55        6  loNeg
# 25        7  loNeg
# 32        7  loNeg
# 49        7  loNeg
# 51       10  loNeg
# 17        7  loNeg
# 0         7  loNeg
# 63        7  loNeg
# 60        8  loNeg
# 62        9  loNeg
# 50        9  loNeg
# 61        8  loNeg
# 23        9  loNeg
# 54        9  loNeg
# 22       20  hiNeg

# %%
# Add indiff and order columns
final_df = final_df.append(indiff, ignore_index = True)
cols = ["Title", "Artist", "Gallery", "Unique ID", "Moved", "Fascinated", "Funny", "Surprised", 
        "Indifferent", "Calm", "Unsettled", "Beautiful", "Arousal", "Group"]
# SEE IF AROUSAL IS NEEDED, ADD "Unique ID" AFTER GALLERY
final_df = final_df[cols]
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
final_df
# Out:
#                                                 Title  \
# 0   Farm Landscape, Cattle in Pasture--Sunset Nant...
# 1                                        Woman Seated
# 2                                   Eve of Saint John
# 3                           Three Pigs and a Mountain
# 4                   Kilauea Caldera, Sandwich Islands
# 5                                    Sunday Afternoon
# 6                                The Arrest of Christ
# 7                          David with Head of Goliath
# 8                              Susanna and the Elders
# 9                                     The Crucifixion
# 10                                        Joseph Sold
# 11                             The Penitent Magdalene
# 12     Madonna and Child with Infant John the Baptist
# 13                                 Maria at La Granja
# 14                              Pool in the Mountains
# 15                                   Afternoon Stroll
# 16                                        Saint Peter
# 17        Portrait of Colonel James Hervey Birch, Jr.
# 18                      Madonna and Child with Angels
# 19                                        Junior Camp
# 20           Still-life Synchromy with Nude in Yellow
# 21                                           Untitled
# 22                             Saint Nicholas of Bari
# 23                                    By the Seashore
# 24                                         Still-life
# 25  Madonna and Child with the Young Saint John th...
# 26                     Portrait of Mrs. William Crane
# 27               Mystical Marriage of Saint Catherine
# 28                            Still-life with Peaches
# 29  The Holy Family with Saints Francis, Anne, and...
# ..                                                ...
# 36                       Elizabeth Crowell with a Dog
# 37                                         Still-life
# 38                                           Mr. Paff
# 39                                   The White Flower
# 40                                    Game of Croquet
# 41                                           Untitled
# 42                                  Madonna and Child
# 43                     Saint Jerome in the Wilderness
# 44                            Late Afternoon, Giverny
# 45                                              Mukie
# 46                         Portrait in Grey and Black
# 47                                         Notre Dame
# 48                      Southern California Landscape
# 49                               Rock ledge in Autumn
# 50                                        Sierra Lake
# 51                                       Morning News
# 52                                  San Felipe Valley
# 53                        Holy Family with Saint Anne
# 54                             The Edge of the Forest
# 55                Flower Garland with the Holy Family
# 56                                     Indian Village
# 57                               Blue, White and Gold
# 58                                    After Many Days
# 59                           The Seine Valley at Mézy
# 60           The Masked Ball at the Elysée Montmartre
# 61                                   The Corn-poppies
# 62                           Tea at Madame Vuillard's
# 63       The Molo from the Basin of San Marco, Venice
# 64                                       Torrey Pines
# 65               The Vision of Saint Anthony of Padua
#
#                                   Artist  Gallery  Unique ID  Moved  \
# 0                          George Inness        2     2008.0      1
# 1                           Hans Hofmann        3     3009.0      1
# 2                                   Hurd      100    10005.0      4
# 3                          George Wesley        3        NaN      2
# 4                        Jules Tavernier        2     2013.0      4
# 5                       Hughie Lee-Smith        3     3005.0      2
# 6                       Hieronymus Bosch       16     1606.0      3
# 7                      Antonio de Bellis       16     1603.0      4
# 8                              de Ribera       16     1628.0      5
# 9                          Martin Bernat       16        NaN      4
# 10                          His Brothers       16        NaN      3
# 11              Giulio Cesare Procaccini       16     1618.0      2
# 17           2      5          2            3     4          1        3.0
# 18           4      1          3            3     4          1        4.0
# 19           3      1          4            2     4          1        4.0
# 20           4      1          4            2     4          1        2.0
# 21           2      4          4            2     4          1        2.0
# 22           4      1          2            4     4          1        3.0
# 23           4      1          3            2     5          1        4.0
# 24           4      1          4            2     5          1        4.0
# 25           4      1          3            3     5          1        5.0
# 26           4      1          4            2     4          1        5.0
# 27           4      1          4            2     5          1        5.0
# 28           5      1          5            2     5          1        5.0
# 29           6      1          3            2     6          1        6.0
# ..         ...    ...        ...          ...   ...        ...        ...
# 36           2      3          3            4     4          1        3.0
# 37           2      1          1            5     5          1        2.0
# 38           2      1          2            5     5          1        3.0
# 39           2      1          2            5     5          1        3.0
# 40           2      1          2            5     5          1        3.0
# 41           2      1          2            5     5          1        3.0
# 42           3      1          1            5     4          1        3.0
# 43           2      2          2            5     5          1        3.0
# 44           2      1          2            4     4          1        3.0
# 45           2      4          2            4     4          1        3.0
# 46           2      1          2            4     4          1        3.0
# 47           3      1          1            4     4          1        3.0
# 48           2      1          2            4     5          1        3.0
# 49           2      1          3            5     5          1        3.0
# 50           3      1          3            3     5          1        4.0
# 51           3      1          3            4     4          1        3.0
# 52           2      1          3            5     5          1        3.0
# 53           3      1          2            5     5          1        3.0
# 54           3      1          3            5     5          1        3.0
# 55           7      1          6            1     5          1        7.0
# 56           2      1          2            5     5          1        3.0
# 57           1      1          2            5     5          1        2.0
# 58           2      1          2            5     5          2        2.0
# 59           2      1          2            5     5          1        3.0
# 60           2      2          1            5     5          1        2.0
# 61           2      2          1            5     5          1        2.0
# 62           2      1          2            5     5          1        2.0
# 63           2      1          2            5     5          1        3.0
# 64           2      1          2            5     5          1        3.0
# 65           2      2          2            6     5          1        3.0
#
#     Arousal   Group
# 0      11.0   hiPos
# 1       8.0   loPos
# 2      15.0   hiPos
# 3       7.0   loPos
# 4      15.0   hiPos
# 5       9.0   loPos
# 6      16.0   hiPos
# 7      14.0   hiPos
# 8      16.0   hiPos
# 9      12.0   hiPos
# 10     11.0   hiPos
# 11      8.0   loPos
# 12      4.0   loNeg
# 13     10.0   loNeg
# 14     16.0   hiNeg
# 15     10.0   loNeg
# 16     11.0   hiNeg
# 17     11.0   hiNeg
# 18     11.0   hiNeg
# 19     11.0   hiNeg
# 20     11.0   hiNeg
# 21     11.0   hiNeg
# 22     10.0   loNeg
# 23     12.0   hiNeg
# 24     12.0   hiNeg
# 25     12.0   hiNeg
# 26     13.0   hiNeg
# 27     13.0   hiNeg
# 28     14.0   hiNeg
# 29     14.0   hiNeg
# ..      ...     ...
# 36     10.0   loNeg
# 37      5.0   loNeg
# 38      6.0   loNeg
# 39      6.0   loNeg
# 40      6.0   loNeg
# 41      6.0   loNeg
# 42      7.0   loNeg
# 43      7.0   loNeg
# 44      7.0   loNeg
# 45     10.0   loNeg
# 46      7.0   loNeg
# 47      7.0   loNeg
# 48      7.0   loNeg
# 49      8.0   loNeg
# 50      9.0   loNeg
# 51      9.0   loNeg
# 52      8.0   loNeg
# 53      9.0   loNeg
# 54      9.0   loNeg
# 55     20.0   hiNeg
# 56      NaN  indiff
# 57      NaN  indiff
# 58      NaN  indiff
# 59      NaN  indiff
# 60      NaN  indiff
# 61      NaN  indiff
# 62      NaN  indiff
# 63      NaN  indiff
# 64      NaN  indiff
# 65      NaN  indiff
#
# [66 rows x 14 columns]

# %%
# Setup sort for rows so that it knows order Group should go in
final_df["Group"] = pd.Categorical(final_df['Group'], ["hiPos", "hiNeg", "loPos", "loNeg", "indiff"])
final_df = final_df.sort_values(['Group','Gallery'])
final_df
# Out:
#                                                 Title  \
# 0   Farm Landscape, Cattle in Pasture--Sunset Nant...
# 4                   Kilauea Caldera, Sandwich Islands
# 6                                The Arrest of Christ
# 7                          David with Head of Goliath
# 8                              Susanna and the Elders
# 9                                     The Crucifixion
# 10                                        Joseph Sold
# 2                                   Eve of Saint John
# 14                              Pool in the Mountains
# 19                                        Junior Camp
# 20           Still-life Synchromy with Nude in Yellow
# 21                                           Untitled
# 33                             Composition with Boats
# 17        Portrait of Colonel James Hervey Birch, Jr.
# 26                     Portrait of Mrs. William Crane
# 24                                         Still-life
# 28                            Still-life with Peaches
# 16                                        Saint Peter
# 18                      Madonna and Child with Angels
# 25  Madonna and Child with the Young Saint John th...
# 27               Mystical Marriage of Saint Catherine
# 29  The Holy Family with Saints Francis, Anne, and...
# 30                       The Coronation of the Virgin
# 31                               Madonna of the Roses
# 55                Flower Garland with the Holy Family
# 23                                    By the Seashore
# 32                                     Seine in Parin
# 1                                        Woman Seated
# 3                           Three Pigs and a Mountain
# 5                                    Sunday Afternoon
# ..                                                ...
# 54                             The Edge of the Forest
# 36                       Elizabeth Crowell with a Dog
# 37                                         Still-life
# 38                                           Mr. Paff
# 46                         Portrait in Grey and Black
# 12     Madonna and Child with Infant John the Baptist
# 22                             Saint Nicholas of Bari
# 35                     Male Saint, perhaps Saint Mark
# 42                                  Madonna and Child
# 43                     Saint Jerome in the Wilderness
# 53                        Holy Family with Saint Anne
# 47                                         Notre Dame
# 15                                   Afternoon Stroll
# 39                                   The White Flower
# 40                                    Game of Croquet
# 48                      Southern California Landscape
# 49                               Rock ledge in Autumn
# 50                                        Sierra Lake
# 52                                  San Felipe Valley
# 13                                 Maria at La Granja
# 56                                     Indian Village
# 57                               Blue, White and Gold
# 58                                    After Many Days
# 65               The Vision of Saint Anthony of Padua
# 59                           The Seine Valley at Mézy
# 60           The Masked Ball at the Elysée Montmartre
# 61                                   The Corn-poppies
# 62                           Tea at Madame Vuillard's
# 64                                       Torrey Pines
# 63       The Molo from the Basin of San Marco, Venice
#
#                                   Artist  Gallery  Unique ID  Moved  \
# 0                          George Inness        2     2008.0      1
# 4                        Jules Tavernier        2     2013.0      4
# 6                       Hieronymus Bosch       16     1606.0      3
# 7                      Antonio de Bellis       16     1603.0      4
# 8                              de Ribera       16     1628.0      5
# 9                          Martin Bernat       16        NaN      4
# 10                          His Brothers       16        NaN      3
# 2                                   Hurd      100    10005.0      4
# 14                          Milton Avery        1     1002.0      1
# 26           4      1          4            2     4          1        5.0
# 24           4      1          4            2     5          1        4.0
# 28           5      1          5            2     5          1        5.0
# 16           5      1          1            3     5          1        4.0
# 18           4      1          3            3     4          1        4.0
# 25           4      1          3            3     5          1        5.0
# 27           4      1          4            2     5          1        5.0
# 29           6      1          3            2     6          1        6.0
# 30           5      1          3            2     5          1        5.0
# 31           5      1          5            3     5          1        5.0
# 55           7      1          6            1     5          1        7.0
# 23           4      1          3            2     5          1        4.0
# 32           6      1          4            2     5          1        6.0
# 1            1      4          2            3     4          2        2.0
# 3            2      1          2            4     4          2        2.0
# 5            3      1          3            3     4          2        3.0
# ..         ...    ...        ...          ...   ...        ...        ...
# 54           3      1          3            5     5          1        3.0
# 36           2      3          3            4     4          1        3.0
# 37           2      1          1            5     5          1        2.0
# 38           2      1          2            5     5          1        3.0
# 46           2      1          2            4     4          1        3.0
# 12           1      1          1            1     1          1        1.0
# 22           4      1          2            4     4          1        3.0
# 35           3      1          3            4     4          1        3.0
# 42           3      1          1            5     4          1        3.0
# 43           2      2          2            5     5          1        3.0
# 53           3      1          2            5     5          1        3.0
# 47           3      1          1            4     4          1        3.0
# 15           3      1          3            3     5          1        4.0
# 39           2      1          2            5     5          1        3.0
# 40           2      1          2            5     5          1        3.0
# 48           2      1          2            4     5          1        3.0
# 49           2      1          3            5     5          1        3.0
# 50           3      1          3            3     5          1        4.0
# 52           2      1          3            5     5          1        3.0
# 13           3      1          4            3     5          1        4.0
# 56           2      1          2            5     5          1        3.0
# 57           1      1          2            5     5          1        2.0
# 58           2      1          2            5     5          2        2.0
# 65           2      2          2            6     5          1        3.0
# 59           2      1          2            5     5          1        3.0
# 60           2      2          1            5     5          1        2.0
# 61           2      2          1            5     5          1        2.0
# 62           2      1          2            5     5          1        2.0
# 64           2      1          2            5     5          1        3.0
# 63           2      1          2            5     5          1        3.0
#
#     Arousal   Group
# 0      11.0   hiPos
# 4      15.0   hiPos
# 6      16.0   hiPos
# 7      14.0   hiPos
# 8      16.0   hiPos
# 9      12.0   hiPos
# 10     11.0   hiPos
# 2      15.0   hiPos
# 14     16.0   hiNeg
# 19     11.0   hiNeg
# 20     11.0   hiNeg
# 21     11.0   hiNeg
# 33     12.0   hiNeg
# 17     11.0   hiNeg
# 26     13.0   hiNeg
# 24     12.0   hiNeg
# 28     14.0   hiNeg
# 16     11.0   hiNeg
# 18     11.0   hiNeg
# 25     12.0   hiNeg
# 27     13.0   hiNeg
# 29     14.0   hiNeg
# 30     14.0   hiNeg
# 31     15.0   hiNeg
# 55     20.0   hiNeg
# 23     12.0   hiNeg
# 32     16.0   hiNeg
# 1       8.0   loPos
# 3       7.0   loPos
# 5       9.0   loPos
# ..      ...     ...
# 54      9.0   loNeg
# 36     10.0   loNeg
# 37      5.0   loNeg
# 38      6.0   loNeg
# 46      7.0   loNeg
# 12      4.0   loNeg
# 22     10.0   loNeg
# 35     10.0   loNeg
# 42      7.0   loNeg
# 43      7.0   loNeg
# 53      9.0   loNeg
# 47      7.0   loNeg
# 15     10.0   loNeg
# 39      6.0   loNeg
# 40      6.0   loNeg
# 48      7.0   loNeg
# 49      8.0   loNeg
# 50      9.0   loNeg
# 52      8.0   loNeg
# 13     10.0   loNeg
# 56      NaN  indiff
# 57      NaN  indiff
# 58      NaN  indiff
# 65      NaN  indiff
# 59      NaN  indiff
# 60      NaN  indiff
# 61      NaN  indiff
# 62      NaN  indiff
# 64      NaN  indiff
# 63      NaN  indiff
#
# [66 rows x 14 columns]

# %%
fs2 = ("output/"+ "pilot02" + "-groupsFINALTEST.csv")
final_df.to_csv(fs2, index=False)

# %%
def evaluate_subject_paintings(inputfilesource, outputsource = None):
    file = pd.read_csv(inputfilesource)
    df = file.sort_values("Indifferent") #lots of indifferent scores are the same...how do you want to further seperate
    indiff = df.tail(10)
    indiff["Group"] = "indiff"

    others = df.iloc[:-10]
    # create arousal (Moved + Fascinated + Funny + Surprised)
    arousal = others['Moved'] + others['Fascinated'] + others['Funny'] + others['Surprised']
    others["Arousal"] = arousal
    
    # add high/low column to others
    others = others.sort_values("Arousal")
    ### middle value split HILOW
    """
    low = others.head(int(len(others)/2))
    low["hilo"] = "lo"
    high = others.tail(int(len(others)/2))
    high["hilo"] = "hi"
    """
    ### Mean value split HILOW
    aro_mean = others["Arousal"].mean() + 0.00001 # making non int should eliminate = mean
    low = others[others["Arousal"] < aro_mean]
    low["hilo"] = "lo"
    high = others[others["Arousal"] > aro_mean]
    high["hilo"] = "hi"
    full_aro = pd.concat([low, high]).sort_values("Unsettled")
    
    
    
    # make pos/neg based off of Unsettled from full_aro
    ### middle value split
    """
    neg = full_aro.head(int(len(full_aro)/2))
    neg["PosNeg"] = "Neg"
    pos = full_aro.tail(int(len(full_aro)/2))
    pos["PosNeg"] = "Pos"
    """
    ### Mean value split
    unset_mean = full_aro["Unsettled"].mean() + 0.00001 # making non int should eliminate = mean
    neg = full_aro[full_aro["Unsettled"] < unset_mean]
    neg["PosNeg"] = "Neg"
    pos = full_aro[full_aro["Unsettled"] > unset_mean]
    pos["PosNeg"] = "Pos"
    
    #merge hilow/posneg and make groups col
    final_df = pd.concat([pos, neg])
    final_df["Group"] = final_df["hilo"] + final_df["PosNeg"]
    final_df = final_df.drop(columns=["hilo", "PosNeg"])
    
    # Add indiff and order columns
    final_df = final_df.append(indiff, ignore_index = True)
    cols = ["Title", "Artist", "Gallery", "Unique ID", "Moved", "Fascinated", "Funny", "Surprised", 
            "Indifferent", "Calm", "Unsettled", "Beautiful", "Arousal", "Group"]
    final_df = final_df[cols]
    
    # Setup sort for rows so that it knows order Group should go in
    final_df["Group"] = pd.Categorical(final_df['Group'], ["hiPos", "hiNeg", "loPos", "loNeg", "indiff"])
    final_df = final_df.sort_values(['Group','Gallery'])
    final_df
    
    if outputsource is None:
        final_df.to_csv(filesource, index=False)
    else:
        final_df.to_csv(outputsource, index=False)

# %%
for subject in unique_subjects:
    evaluate_subject_paintings("output/"+ subject + "-groups.csv", outputsource = "output/"+ subject + "-groupsGROUPED.csv")
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
